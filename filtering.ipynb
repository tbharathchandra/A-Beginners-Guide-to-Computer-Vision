# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize

# %%
from skimage import io 
from scipy import ndimage

# %%
img = io.imread("lena.jpg")
type(img)
img = resize(img, (340, 340),
                       anti_aliasing=True)
plt.imshow(img)
plt.show()
# Out:
# imageio.core.util.Array

# %%
red_img = img.copy()
red_img[:,:,1] = 0
red_img[:,:,2] = 0
plt.imshow(red_img)
plt.show()

# %%
blue_img = img.copy()
blue_img[:,:,0] = 0
blue_img[:,:,1] = 0
plt.imshow(blue_img)
plt.show()

# %%
plt.imsave("red_img.jpg",red_img)
plt.imsave("green_img.jpg", green_img)
plt.imsave("blue_img.jpg", blue_img)
plt.imsave("img.jpg", img)

# %%
from skimage.color import rgb2gray

# %%
mean_mask = np.ones((7,7))
grey_img = rgb2gray(img)
plt.imshow(grey_img, cmap = plt.get_cmap('gray'))
plt.show()
mean_img = ndimage.convolve(grey_img, mean_mask, mode = 'constant', cval = 0.0)
plt.imshow(mean_img, cmap = plt.get_cmap('gray'))
plt.show()

# %%
from scipy import signal

def gkern(kernlen=21, std=3):
    gkern1d = signal.gaussian(kernlen, std=std).reshape(kernlen, 1)
    gkern2d = np.outer(gkern1d, gkern1d)
    return gkern2d

# %%
gkern(3,3)
# Out:
# array([[0.89483932, 0.94595947, 0.89483932],
#        [0.94595947, 1.        , 0.94595947],
#        [0.89483932, 0.94595947, 0.89483932]])

# %%
sizes=[3,5,7]
for i in sizes:
    gaussian_img = ndimage.convolve(grey_img, gkern(i,3), mode = 'constant', cval = 0.0) #sigma = 3.0
    plt.imshow(gaussian_img, cmap = plt.get_cmap('gray'))
    plt.show()

plt.imshow(grey_img, cmap = plt.get_cmap('gray'))
plt.show()
